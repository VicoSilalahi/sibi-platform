# %% [markdown]
# # SIBI Platform: Cloud Training (Google Colab)
#
# Use this notebook to train your GRU models using Google Colab's hardware (GPU/TPU).
#
# ### 🚀 Faster Workflow:
# 1. **Git Clone**: Run the cell below to pull your latest code.
# 2. **Upload Data**: Upload `datasets.zip` **into the `sibi-platform/` folder** created by git clone.
# 3. **Train**: Run the training cells.

# %%
# 1. Clone the repository
# !git clone https://github.com/YOUR_USERNAME/sibi-platform.git
print("✅ Code cloned successfully.")

# %%
# 2. Unzip the dataset
# Note: Upload datasets.zip INTO the sibi-platform/ folder first!
# %cd sibi-platform
# !unzip -q datasets.zip
print("✅ Dataset unzipped successfully.")

# %%
# 3. Install dependencies & CuDNN Fix
# When forcing Python 3.11.9, we need to ensure the GPU libraries match
# !pip install opencv-python mediapipe tensorflow scikit-learn numpy
# !pip install nvidia-cudnn-cu12==9.3.0.75
print("✅ Dependencies and Compatibility Fix installed.")

# %%
# 4. Run Camera Training
# Set environment variables to fix Matplotlib and Force GPU Growth
# %env PYTHONPATH=.
# %env MPLBACKEND=Agg
# %env TF_FORCE_GPU_ALLOW_GROWTH=true
# !python -m app.training.train_camera

# %%
# 5. Run Glove Training
# %env PYTHONPATH=.
# %env MPLBACKEND=Agg
# !python -m app.training.train_glove

# %% [markdown]
# ### 📥 After Training:
# 1. Download your model from `app/models/saved_models/`.
# 2. Commit your code changes if you made any in the cloud!
